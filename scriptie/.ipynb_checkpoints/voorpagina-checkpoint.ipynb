# %% [markdown]
# Voorpagina
# =======================

# %%
import os
import pandas as pd
from zipfile import ZipFile
import numpy as np
import plotly.express as px
import seaborn as sb
import matplotlib.pyplot as plt
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder
import re

os.getcwd()

# Download BRON
#!wget https://www.rijkswaterstaat.nl/apps/geoservices/geodata/dmc/bron/01-01-2010_31-12-2019.zip
# Out:
# '/mnt/c/Users/stijn/OneDrive/Bureaublad/Afstudeerproject/afstudeerproject_repo/scriptie'

# %% [markdown]
# ### Data Pre-Processing

# %%
# !ls

# Locate BRON.zip
# !ls -l 01-01-2010_31-12-2019.zip
# Out:
# 01-01-2010_31-12-2019.zip  _toc.yml	     introductie.md   references.bib
# Data			   abstract.md	     markdown.md      referentie.md
# _build			   images	     methoden.md      requirements.txt
# _config.yml		   inhoudsopgave.md  notebooks.ipynb  voorpagina.ipynb
# -rwxrwxrwx 1 smwhering smwhering 186927157 Jul 20  2020 01-01-2010_31-12-2019.zip

# %%
# Regex pattern to match names of .txt files in dataset
regex = '([^\/]+(?=\.txt))'
  
# specifying the zip file name
file_name = "01-01-2010_31-12-2019.zip"
  
# opening the zip file in READ mode
with ZipFile(file_name, 'r') as zipf:
    # printing all the contents of the zip file
    df_dct = {}
    
    # Create a dict with al the dataframe .txt tables, the key is the name of this table
    for df in zipf.namelist(): 
        if '.txt' in df and 'Definitie' not in df:
            # Select the name of the .txt data files
            name = re.findall(regex, df)[0] + '_df'
            if name == 'ongevallen_df':
                ongevallen_df = pd.read_csv(zipf.open(df, mode='r'), encoding = 'ISO-8859-1')
                # Drop AVG columns and columns that consist of more then 60% of NaN values
                ongevallen_df.drop(['DATUM_VKL', 'DAG_CODE', 'TIJDSTIP', 'DDL_ID', 'AP4_CODE', 'AP5_CODE', 'ANTL_SLA', 'ANTL_DOD', 'ANTL_GZH', 'ANTL_SEH', 'ANTL_GOV', 'ANTL_TDT'], axis=1,  inplace=True)
                
                print(ongevallen_df.shape)
                threshold = int(len(ongevallen_df) * 0.70)
                ongevallen_df.dropna(axis=1, how='all',thresh=threshold,  inplace=True)
                print(ongevallen_df.shape)
                # Add to df dictionary
                df_dct[name] = ongevallen_df
                
            if name == 'partijen_df':
                partijen_df = pd.read_csv(zipf.open(df, mode='r'), encoding = 'ISO-8859-1')
                print(partijen_df.shape)
                threshold = int(len(partijen_df) * 0.70)
                # Drop AVG columns and columns that consist of more then 60% of NaN values
                partijen_df.drop(['NTT_CODE_V', 'GEBDAT', 'GEBJAAR', 'LEEFTIJD', 'NTT_CODE_B', 'BLAASTEST', 'ART8', 'MEDICGEBR', 'TDT_ID_1', 'TDT_ID_2', 'TDT_ID_3'], axis=1,  inplace=True)
                partijen_df.dropna(axis=1, how='all', thresh=threshold, inplace=True)
                print(partijen_df.shape)
                # Add to df dictionary
                df_dct[name] = partijen_df
            else:
                data = pd.read_csv(zipf.open(df, mode='r'), encoding = 'ISO-8859-1')
                # Drop 
                data.dropna(axis=1, how='all', inplace=True)
                df_dct[name] = data
# Out:
# /home/smwhering/miniconda3/envs/datasc/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (6,7,8,29,31,33,35,37) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/smwhering/miniconda3/envs/datasc/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (1,2,24,25,29,31,34,35,39,43,47,52,64) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (1128636, 54)
# (1128636, 15)
# /home/smwhering/miniconda3/envs/datasc/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (1,2,24,25,29,31,34,35,39,43,47,52,64) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/smwhering/miniconda3/envs/datasc/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (29,31,36,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (1224079, 41)
# (1224079, 4)

# %%
# # Check the dataframes
# for df in df_dct:
#     print('Name of dataframe: {}'.format(df))
#     display(df_dct[df].head())

# %% [markdown]
# #### Ongevallen

# %% [markdown]
# We selecteren features die van belang zijn bij verkeersongevallen, features verwijzen naar data die redundant is voor het onderzoek.

# %%
print(df_dct['ongevallen_df'].columns)

# Features with id or pair-values that can be used in this research.
filterL = ['VKL_NUMMER', 'AP3_CODE', 'ANTL_PTJ', 'AOL_ID', 'NIVEAUKOP', 'WSE_ID',
           'WSE_AN', 'BEBKOM','MAXSNELHD', 'WVL_ID', 'WVG_ID', 'WVG_AN','WDK_ID',
           'WDK_AN', 'LGD_ID', 'ZAD_ID', 'WGD_CODE_1', 'WGD_CODE_2', 'BZD_ID_VM1',
           'BZD_ID_VM2','BZD_ID_VM3', 'BZD_VM_AN', 'BZD_ID_IF1', 'BZD_ID_IF2',
           'BZD_IF_AN','BZD_ID_TA1', 'BZD_ID_TA2', 'BZD_TA_AN',
           'FK_VELD5', 'GME_NAAM','PVE_NAAM','IND_ALC']

ongevallen_sub = df_dct['ongevallen_df'].loc[:, (filterL)]
df_total = ongevallen_sub.merge(df_dct['partijen_df'], on='VKL_NUMMER').set_index(['PTJ_ID', 'VKL_NUMMER', 'FK_VELD5'])
display(df_total.info())
display(df_total.head())
# Out:
# Index(['VKL_NUMMER', 'REGNUMMER', 'PVOPGEM', 'JAAR_VKL', 'AP3_CODE',
#        'ANTL_PTJ', 'AOL_ID', 'NIVEAUKOP', 'WSE_ID', 'WSE_AN', 'BEBKOM',
#        'MAXSNELHD', 'WVL_ID', 'WVG_ID', 'WVG_AN', 'WDK_ID', 'WDK_AN', 'LGD_ID',
#        'ZAD_ID', 'WGD_CODE_1', 'WGD_CODE_2', 'BZD_ID_VM1', 'BZD_ID_VM2',
#        'BZD_ID_VM3', 'BZD_VM_AN', 'BZD_ID_IF1', 'BZD_ID_IF2', 'BZD_IF_AN',
#        'BZD_ID_TA1', 'BZD_ID_TA2', 'BZD_TA_AN', 'JTE_ID', 'WVK_ID',
#        'HECTOMETER', 'FK_VELD5', 'HUISNUMMER', 'GME_ID', 'GME_NAAM',
#        'PVE_CODE', 'PVE_NAAM', 'KDD_NAAM', 'PLT_NAAM', 'DIENSTCODE',
#        'DIENSTNAAM', 'DISTRCODE', 'DISTRNAAM', 'IND_ALC'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1224079 entries, (25387133, 20110060504, 'WVK0261442006') to (28156355, 20190078934, 'WVK0403127004')
# Data columns (total 32 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   AP3_CODE    1224079 non-null  object
#  1   ANTL_PTJ    1224079 non-null  int64
#  2   AOL_ID      1224079 non-null  int64
#  3   NIVEAUKOP   1224079 non-null  object
#  4   WSE_ID      1088378 non-null  float64
#  5   WSE_AN      300 non-null      object
#  6   BEBKOM      927439 non-null   object
#  7   MAXSNELHD   1039808 non-null  float64
#  8   WVL_ID      1074245 non-null  float64
#  9   WVG_ID      1063267 non-null  float64
#  10  WVG_AN      5207 non-null     object
#  11  WDK_ID      1064466 non-null  float64
#  12  WDK_AN      2892 non-null     object
#  13  LGD_ID      815109 non-null   float64
#  14  ZAD_ID      29 non-null       float64
#  15  WGD_CODE_1  1051296 non-null  object
#  16  WGD_CODE_2  793 non-null      object
#  17  BZD_ID_VM1  115087 non-null   float64
#  18  BZD_ID_VM2  8253 non-null     float64
#  19  BZD_ID_VM3  481 non-null      float64
#  20  BZD_VM_AN   4106 non-null     object
#  21  BZD_ID_IF1  54296 non-null    float64
#  22  BZD_ID_IF2  25 non-null       float64
#  23  BZD_IF_AN   77172 non-null    object
#  24  BZD_ID_TA1  22080 non-null    float64
#  25  BZD_ID_TA2  334 non-null      float64
#  26  BZD_TA_AN   415 non-null      object
#  27  GME_NAAM    1224079 non-null  object
#  28  PVE_NAAM    1224079 non-null  object
#  29  IND_ALC     109947 non-null   object
#  30  NUMMER      1224079 non-null  int64
#  31  OTE_ID      1163309 non-null  float64
# dtypes: float64(15), int64(3), object(14)
# memory usage: 385.5+ MB
# None
#                                    AP3_CODE  ANTL_PTJ  AOL_ID NIVEAUKOP  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006      LET         2       6         E
# 25387134 20110060504 WVK0261442006      LET         2       6         E
# 25387135 20110060555 WVK0219488003      LET         1       9         S
# 25387138 20110060600 WVK0224440001      LET         2       4         E
# 25387139 20110060600 WVK0224440001      LET         2       4         E
#
#                                     WSE_ID WSE_AN BEBKOM  MAXSNELHD  WVL_ID  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006     1.0    NaN    NaN        NaN     3.0
# 25387134 20110060504 WVK0261442006     1.0    NaN    NaN        NaN     3.0
# 25387135 20110060555 WVK0219488003     2.0    NaN    NaN        NaN     NaN
# 25387138 20110060600 WVK0224440001     1.0    NaN    NaN       30.0     2.0
# 25387139 20110060600 WVK0224440001     1.0    NaN    NaN       30.0     2.0
#
#                                     WVG_ID  ... BZD_ID_IF2  BZD_IF_AN  \
# PTJ_ID   VKL_NUMMER  FK_VELD5               ...
# 25387133 20110060504 WVK0261442006     2.0  ...        NaN        NaN
# 25387134 20110060504 WVK0261442006     2.0  ...        NaN        NaN
# 25387135 20110060555 WVK0219488003     NaN  ...        NaN        NaN
# 25387138 20110060600 WVK0224440001     4.0  ...        NaN        NaN
# 25387139 20110060600 WVK0224440001     4.0  ...        NaN        NaN
#
#                                    BZD_ID_TA1  BZD_ID_TA2  BZD_TA_AN  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006        NaN         NaN        NaN
# 25387134 20110060504 WVK0261442006        NaN         NaN        NaN
# 25387135 20110060555 WVK0219488003        NaN         NaN        NaN
# 25387138 20110060600 WVK0224440001        NaN         NaN        NaN
# 25387139 20110060600 WVK0224440001        NaN         NaN        NaN
#
#                                       GME_NAAM       PVE_NAAM  IND_ALC  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006   Medemblik  Noord-Holland      NaN
# 25387134 20110060504 WVK0261442006   Medemblik  Noord-Holland      NaN
# 25387135 20110060555 WVK0219488003  Den Helder  Noord-Holland      NaN
# 25387138 20110060600 WVK0224440001     Alkmaar  Noord-Holland        J
# 25387139 20110060600 WVK0224440001     Alkmaar  Noord-Holland        J
#
#                                     NUMMER  OTE_ID
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006       1    64.0
# 25387134 20110060504 WVK0261442006       2    64.0
# 25387135 20110060555 WVK0219488003       1     NaN
# 25387138 20110060600 WVK0224440001       1    62.0
# 25387139 20110060600 WVK0224440001       2    83.0
#
# [5 rows x 32 columns]

# %% [markdown]
# #### Alternatieven antwoorden

# %%
alternatieve_cols = [col for col in df_total if '_AN' in col]

# Check the alternative answers for road related issues that caused the incident. 
for col in alternatieve_cols:
    print(col)
    display(df_total[col].loc[df_total[col].notnull()].unique())
    
    
    
# Gebruik columns zonder alternatieven
cols_zondAlt = df_total.columns.difference(alternatieve_cols)
# Out:
# WSE_AN
# array(['VERANDERING VAN WEGSITUATIE', 1.0, 6.0, 5.0, 2.0, 4.0, 3.0,
#        'SPOORWEG OVERGANG'], dtype=object)
# WVG_AN
# array(['Tegels', 'keien', 'Zand', 'Overig', 'Grind', 'hout',
#        'kinderkopjes', 'stenen', 'gras', 'onverhard', 'tramrails',
#        'Keien', 'stelkonplaatsen', 'stalen platen', 'Modder', 'rails',
#        'dab', 'KEIEN', 'ZAND', 'BITUMEN', 'grit', 'schelpen', 'besmeurd',
#        'kinderkoppen', 'beton tegels', 'straatstenen', 'marmer',
#        'betonnen tegels', 'betontegels', 'ZANDPAD', 'TEGELS', 'ASFALT',
#        'ZAND EN GRIND', 'TRAMBAAN', 'BRUG', 'STOEPTEGELS',
#        'BETONTEGELS 30X30', 'BETON TEGELS 30X30', 'TEGELS EN FIETSPAD',
#        'TROTTOIRTEGELS', 'VREESVAKKEN', 'ROOD ASFALT', 'GRINDPAD',
#        'VOETGANGERSOVERSTEEKPLAATS', 'GRAVEL', 'FIETSPAD', 'DAP',
#        'HALF VERHARDE WEG', 'SCHELPENPAD', 'ASPHALT',
#        'NATUURSTEEN TEGELS', 'COMBI RIJPLATEN KLINKERS', 'GRIND SCHELPEN',
#        'TEGELS STENEN ', 'BITUMEN EN KLINKERS', 'ONBEKEND', 'RIJPLATEN',
#        'TEGELS FIETSPAD ', 'DAB', 'NORMAAL FIETSPAD', 'ZAND EN GROND',
#        'STRAATTEGELS', 'TEGELS 30 BIJ 30', 'GRINT', 'KUNSTSTOF PLATEN',
#        'RAILS', 'BETONTEGELS FIETSPAD ', 'AFSVALT', 'GRAS',
#        'ASFALT MET DICHTE STRUCTUUR', 'ASFALT EN TEGELS KLINKERS',
#        'ZAND EN KIEZELS', 'ZANDWEG', 'GEEN ZAND GRIND', 'TRAMHALTE',
#        'TEGELS IVM UITRITCONSTRUCTIE', 'STENEN', 'GLAD WEGDEK',
#        'ZOAB OVERGAAND IN KLINKERS', '30 30 TEGELS',
#        'STENEN 30 BIJ 30 CM', 'ASFALT ', 'STEENGRUIS',
#        'STOEPTEGELS OP HET FIETSPAD', 'ASVALT',
#        'HOUTENBRUG MET ANTISLIP LAAG', 'STALEN RIJPLATEN', 'BETONTEGELS',
#        'TREINRAILS', 'BOS', 'STOEPTEGEL', 'TEGELBESTRATING',
#        'STOEPTEGELS 30 X 30', 'BETON TEGELS', 'RODE FIETSPADTEGELS',
#        'GRIND', 'BETONNEN RIJPLATEN', 'ONVERHARD', 'KLEI', 'ZANDGROND',
#        'DEELS VERHARD DEELS ONVERHARD', 'WERK IN UITVOERING PLATEN',
#        'SPOOR', 'FIETSPADTEGELS', 'METALEN WILDROOSTER', 'KEIEN EN ZAND',
#        'RODE TROTTOIR TEGELS', 'TRAMRAILS BITUMEN', 'SCHELPEN',
#        'RODE FIETSPAD TEGELS', 'TEGELS 30 X 30', 'NIEUW ASFALT', 'HOUT',
#        'VAN KLINKERS NAAR BITUMEN', 'N V T ', 'RAILS EN BITUMEN',
#        'GRASLAND', '30X30 TEGELS', 'ASTFALT', 'ROLBAND',
#        'STALEN RIJ PLATEN', 'GRAS EN RAILS', 'STEENMASTIEK ASFALT',
#        'STRAAT TEGELS', '30 BIJ 30CM TEGELS', 'RODE STOEPTEGELS',
#        'BITUM KLINKERS EN PUTDEKSEL', 'SPOORRAILS',
#        'PLATEN VAN DE BOUWPLAATS', 'VERHARD ZAND', 'BETONSTENEN',
#        'WEGBESTRATING', '30X30CM TEGELS ROZE', 'ZAND GRIND',
#        'TEGELS FIETSPAD', 'KLINKERS OF KEIEN', '30 X 30 TEGELS',
#        'BETON EN GRIND', 'METALEN RIJPLAAT', 'GRAS ZANDWEG',
#        'TEGELS EN KLINKERS', 'ZAND EN GRIND EN BLADEREN', 'GRINT ASVALT',
#        'GEEN WEG IS OPENGEBROKEN', 'ZO N LEKDICHTE ONDERGROND',
#        'GRIND BOUWWEG', 'KEPPING BAAN EN ZAND', 'PONDVLOER',
#        'ONVERHARDE WEG', 'STOEPTEGELS 30X30', 'VERHARD FIETSPAD',
#        'SPLIT STEENTJES', 'VLOEISTOF DICHTE MATREAAL',
#        'DEELS BITUMEN DEELS KLINKERS', 'ZAND SCHELPENPAD',
#        'STOEPTEGELS LOSLIGGEND ', 'ASFALT MOGELIJK ZOAB',
#        'ZOAB EN KLINKERS', 'WATER', 'SPOORSTAVEN', 'TRAMRAILS',
#        'TEGELS 30 BIJ 30 CM', 'ONVERHARD KIEZEL', 'BITUMEN EN KEIEN',
#        'ASVALT MET LOSLIGGEND GRIND', '40 40 TEGELS', '30X30 RODE TEGELS',
#        'VIERKANTE TEGELS ', 'SPOORWEGOVERGANG', 'TROTTOIR TEGELS',
#        'TEGELS ROOD ', 'FIETSPAD TEGELS', 'GRIND MET RAILS',
#        'VLOEISTOFDICHTE TEGELS', 'KINDERKOPJES', 'STOEP',
#        'ONVERHARD GREVEL ', 'BETONPLATEN', 'GEEN ',
#        'RODE TROTTOIRTEGELS FIETSPAD ', 'JAPANS GRANIET', 'SCHELPENZAN D',
#        'GRINDWEG', 'BOSPAD', 'FIETSPAD KLEINE STEENTJES',
#        'RECHTHOEKIGE STENEN', 'KLINKERS NAAR BITUMEN', 'ZANDQWEG', 'NVT',
#        'VLOER MET COATING ', 'KIEZELTJES', 'BERM', 'ZAND MET STEENTJES',
#        'GLADDE TEGELS', 'VERHARD MIDDELS GRAVEL', 'KIEZEL', ' ',
#        'GRIND PUIN', 'TEGELS EN ASFALT', 'KLINKERS EN BITUMEN',
#        'ASFALT EN KLINKERS', 'BOSPAD ZAND', 'STEEN', 'RODE TEGELS',
#        'STRAATSTENEN', 'ASFALT EN GRIND', 'RODE 30X30 TEGELS', 'GEEN',
#        'STENEN TEGELS', 'ZAND MODDER', 'BRUGBEDEKKING', 'STELCONPLAAT',
#        'AFVALT', 'KIEZELS', 'BETON PLATEN', 'STOEPTEGELS FIETSPAD',
#        'GRINDPAD KIEZELSTENEN', 'GRIND ', 'KLINKERS BITUMEN',
#        'FIETSPLATEN', 'ZAND EN VLONDERPLATEN', 'BOUWPLATEN',
#        'BETUM KRUISING IS BEKLINKERT', 'TEGELS TROTTOIR', 'RUBBER',
#        'ZAND EN STENEN', 'BITUMEN MET SPLIT', 'WEILAND', 'ROOD ROLSPLIT',
#        'ZAND GRINT', 'GRASVELD', 'TROITTOIRTEGELS', 'HOUTEN VLONDER',
#        'BITUMEN MET GRIND SLIJTLAAG', 'ONVERHARDEWEG',
#        'RODE GRAVEL FIETSPAD', 'TEGELS PLEIN', 'VERHARDE TRAMBAAN',
#        '30 BIJ 30 TEGELS FIETSPAD', 'GEWONE BESTRATING',
#        'KLINKERS EN METALEN PUTDEKSEL', 'ZAND EN GRINT', 'STRUIKEN',
#        'ZAND ONVERHARD', 'VLONDER', 'KLINKERS MET DAAROP ZANDLAAG',
#        'BOOM', 'ZAND BETON ASFALT', 'TEGELFIETSPAD', 'ZAND STEEN',
#        'KLINKERS EN TEGELS', 'ALUMINIUM', 'ZOAB', 'WILDROOSTER',
#        'RUW ASFALT', 'ZANDGRIND', 'ZAND EN SCHELPENPAD',
#        'BITUMEN EN TRAMRAILS', 'NATUURSTEEN', 'BITUMEN MET LOSSE KORRELS',
#        'KLINKERS BITUMEN SPOOR', 'FIJNE GRIND', 'OUDERWETSE STRAATSTENEN',
#        'BITUMEN UITRIT KLINKERS ', 'ONVERHARD GRAVEL',
#        'BETONNEN GRINDTEGELS', 'GRINDSTEENTJES GRIT', 'BITUMEN EN TEGELS',
#        'POND', 'NIET AANWEZIG', 'TEGELS BETON', 'PUINPAD', 'MODDER',
#        'DEELS BITUMEN DEELS TEGELS', 'RIJ PLATEN', 'TUIN',
#        'BETONPLATEN ASFALT EN ZAND', 'METAAL', '30 BIJ 30 STRAATSTENEN',
#        'GEEN WEGVERHARDING', 'PARKEERGARAGE', 'BETONNEN TEGELS',
#        'ZAND MET ASFALT', 'BETEGELD', 'ZAND EN BETON', 'GRAS BERM ',
#        'GEWONE TEGELS', 'IN PARKEERGARAGE', 'STEENTJES GRIND',
#        'THERMO FLEX', 'GRID ZAND KLEI', 'RODE STOEPTEGELS ',
#        'PLATEN VAN BETON', 'ASFALT FIETSPAS',
#        'ONDERGROND BENZINE STATION', 'GROND', 'ZAND EIGEN TERREIN',
#        'VLOEISTOFDICHTE VLOER', 'TEGELS 20 BIJ 20 CM',
#        'GRANIET TEGELS FIETSPAD ', 'KLINKERS VS BITUMEN', '30X30',
#        'BETON EN TRAMBAAN', '30 30 BETONTEGELS', 'ASFALTWEG',
#        'VERHARD MET KIEZELS GRINT', 'STELCONPLATEN', 'ZAND EN PUIN',
#        'KIEZEL OP DE OPRIT', 'ONVERHARD ZANDPAD', 'BRUG LATTEN',
#        'ZAND STENEN', 'VERMOEDELIJK ZANDWEG', ' STOEP TEGELS',
#        'GEEN IDEE NIET TP GEWEEST', 'STENEN STRAAT TEGELS',
#        'ZANDWEG MET GRIT', 'COMBINATIE ZAND EN BITUMEN',
#        'ZAND EN DEEL ASFALT', 'BERMGRAS EN ASFALT', 'TEGELS 30 X 30 CM',
#        'STELCON PLATEN', 'TEGELS 30X30', 'RODE TROITTOIR TEGELS',
#        'BITUMEN STENEN RANDEN', 'GRAS ZAND', '30X30 STOEPTEGELS',
#        'GRAS GROND', 'IJZER', 'TROTTOIR', 'KUNSTSTOF RIJPLATEN ',
#        'SCHELPENVERHARDING', 'GEFREESD BITUMEN', 'ONVERHARD ZAND',
#        'ZAND GRUIS', 'PLATEN', 'KLINKERS EN ZOAB', 'MIDDENBERM TRAMBAAN',
#        'SNELWEG', 'HOUTEN BEPLATING', 'KLINKERS EN ASFALT',
#        'DAB DICHT ASFALT BETON', 'AARDE', 'STRAAT STENEN',
#        ' HARD ZAND EN STENEN', 'STAAL', 'NIET BEKEND',
#        'STOEPTEGELS 30 BIJ 30 CM', 'PLANTSOEN', 'STOEP TEGELS',
#        'GEEN IDEE', 'TRAMBAAN BUSBAAN', 'VAN KLINKERS NAAR BETUMEN',
#        'ROOD ASVALT', 'HOUT POLYMEER', 'HOUT MET KORRELS',
#        'TROTTOIRTEGELS FIETSPAD', 'TRAMSPOOR MET STENEN ER TUSSEN',
#        'STOEPSTEGELS', 'GRINTWEG', 'DEELS KLINKERS DEELS BITUUM',
#        'GRASSTROOK', 'BESTRATING', 'BESTRAAT WEGDEK', 'WASSTRAAT',
#        'HOUT COMPOSIET VLONDERDELEN', 'ROOD GEVERFD BITUMEN',
#        'VEE ROOSTER', 'KLINKERS', 'GRAS BERM',
#        'LANDWEG ASFALT MET KEIEN ', 'GRIND ZAND',
#        'STRAATTEGELS 30 X 30 CM ', 'GRASVELD NABIJ ONVERHARD PAD',
#        'KINDERKOPJES KLINKERS ', 'SPOORBAANVAK', 'WEGDEK WAS ER DEELS AF',
#        'MODDER TUSSEN DE TRAMBAAN', 'CEMENT', 'BETON UITRIT KLINKERS',
#        'ZAND BERM', '30X30 BETONNEN STRAATTEGELS', 'NORMALE BESTENING',
#        'ASFAVLT', 'ZOAB KLINKERS', 'TEGELS REGULIER FIETSPAD',
#        'STOEPTEGELS 30 CM X 30 CM', 'GRIND STEENTJES', 'IJZEREN PLATEN ',
#        'TRAMBAAN MET KLINKERS', 'BETONSTRAATSTENEN',
#        'ROZE TEGELS VAN FIETSPAD', 'ZAND GRAVELPAD', 'OUD ASFALT',
#        'BITUMEN EN GRAS', 'TEGELS ', 'PLAVUIZEN', 'TEGELS 30X 30',
#        'GRIND ASFALT', 'FIETSPAD ROODKLEURIG ASFALT', 'KLINKERS EN KEIEN',
#        'DAB DICHT ASFALT BETON ', 'SPLIT', 'BITUMEN EN GRAVEL',
#        'COBBLESTONES', 'GROENSTROOK', 'RAILS EN KLINKERS', 'SOORT TEGELS',
#        'BITUMEN MET OVERDADIG GRIT', 'STRAATTEGELS 30 30', 'TEGELVLOER',
#        'VAN ALLES', 'KASSEIEN', 'TEGEL'], dtype=object)
# WDK_AN
# array(['Besmeurd', 'inveegzand', 'los grind', 'onverhard', 'overige',
#        'grind', 'zonnig', 'glad', 'BESMEURD', 'zand op wegdek',
#        'BITUMEN/TEER', 'KIEZELS', 'WEEK UIT VOOR TUIN SPROEIER', 'WEGDEK',
#        'HIER EN DAAR WAT VOCHT ', 'BEVROREN OPPERVLAKTE',
#        'BEWEEGBARE PAAL IN WEGDEK', 'VAN STOEPRAND NAAR WEGDEK',
#        'ONBEKEND', 'PAAL IN WEGDEK', 'GLAD IVM OPVRIEZING',
#        'LAG ZAND OP ', 'TRAMRAILS IN HET WEGDEK', 'GLAD DOOR BEVRIEZING',
#        'BULT IN WEGDEK DOOR BOOMWORTEL', 'PAALTJE IN WEGDEK GERAAKT',
#        'ZAND GRIND OP HET WEGDEK', 'METALEN RIJPLATEN', 'SLECHT WEGDEK',
#        'GLAD WEGDEK IVM OPVRIEZEN', 'AFVAL WIELDOP OP HET WEGDEK ',
#        'LOS ASVALT', 'WEGGEFREESD', 'GLAD WEGDEK DOOR BEVRIEZING',
#        'PLAATSELIJK DOOR KOU ERG GLAD', 'WEGDEK ZEER SLECHT',
#        'GLAD DOOR OPVRIEZEN WEGDEK', 'VALPARTIJ DOOR ZAND OP WEGDEK',
#        'ASFALT', 'OVER EEN HEUVEL IN HET WEGDEK', 'GLAD',
#        'WEGDEK BESCHADIGD', 'GLAD BEVROREN', 'SPLIT OP DE WEG',
#        'MOGELIJK OPGEVROREN WEGDEK', 'GLAD A G V OPVRIEZEN',
#        'SLIPTE EN VIEL OP HET WEGDEK', 'GLAS AGV BEVRIEZING',
#        'DROOG ONDER DE VOERTUIGEN ', 'STEEN OP WEGDEK', 'GRASVELD',
#        'BEZAAID MET GRIND', 'DEELS VERHARD DEELS ONVERHARD',
#        'OP HET WEGDEK LIGGENDE PERSOON', 'ZAND', 'TRAMBAAN',
#        'LOSLIGGENDE TEGELS', 'GEVALLEN DOOR GLAD WEGDEK', 'WEILAND',
#        'SLECHT WEGDEK IS ONGELIJK', 'OLIE OP HET WEGDEK',
#        'TRAMBAAN IN WEGDEK', 'NIEUW WEGDEK',
#        'VALPARTIJ OVER SLECHT WEGDEK ', 'NIEUW ASFALT',
#        'BESMEURD MET OLIE', 'LOSLIGGEND GRIND', 'GRAS', 'GRASLAND',
#        'DOOR OPVRIEZING IJZEL SPEKGLAD', 'ZANDERIG',
#        'VERKEERSDREMPELS IN WEGDEK', 'TEGELS', 'SLANG OVER WEGDEK',
#        'OPGEVROREN', 'IJZEREN PLATEN OP HET WEGDEK', 'SPOORSTAVEN',
#        'BEVROREN', 'UITGEGLEDEN DOOR NAT WEGDEK',
#        'WAARSCHUWINGSBALK BOVEN WEGDEK', 'IJZEL',
#        '1ZIJDIG WEGGEGLEDEN OP WEGDEK', 'ONVERHARDE WEG',
#        'SNEEUW OP WEGDEK', 'LICHT VOCHTIG', 'GLAD OPGEVROREN VOCHT',
#        'VERSE SPLIT', 'HOOP ZAND ONDERLAAG WEGDEK',
#        'GELUIDSCHERM VANGRAIL WEGDEK', 'LICHT GLAD VAN DE VORST',
#        'GLAD WEGDEK', 'ONDERUIT DOOR GLAD NAT WEGDEK ', 'GLAD DOOR KOU ',
#        'LOS GRIND', 'GLAD IJS', 'BEVROREN WEGDEK',
#        'GROTE WATERPLAS OP HET WEGDEK', 'TRAMRAILS IN WEG',
#        'PLAATSELIJK GLAD', 'GEEN IDEE', 'VERDRIJVINGSKRUIS OP WEGDEK',
#        'OPVRIEZING', 'DIESEL OP DE WEG', 'METALEN VOORWERP OP WEGDEK',
#        'TANKSTATION', 'BOSPAD', 'ZAND OP WEGDEK', 'IJSEL',
#        'ZAND DOOR EEN OPBREKING', 'NAT EN MODDERIG', 'DREMPEL WEGDEK',
#        'OPGEVROREN DOUW ', 'UITGEGLEDEN OP GLAD WEGDEK', 'BITUMEN',
#        'VERMOEDELIJK BESNEEUWT', 'VOCHTIG GLAD DOOR OPVRIEZEN',
#        'PLAATSELIJK GLAD DOOR VORST', 'GLADHEID IVM VORST', 'WATER',
#        'DIJK', 'GRASSTROOK', 'DROOG LAAGSTAANDE ZON ',
#        'NAT VOCHTIG MOGELIJK BEVROREN', 'ONBEKEND BIJ VERBALISANT',
#        'EENZIJDIG WEGDEK', 'DOOR BEVRIEZING GLAD',
#        'DROOG MAAR PLAATSELIJK GLAD ', 'AANGEVROREN',
#        'METALEN PLAAT OP HET WEGDEK', 'NIET BEKEND',
#        'DIJKWEG SLECHT EN BOL WEGDEK ', 'GRIND OP HET WEGDEK',
#        'LICHT OPGEVROREN', 'OP VRIEZEN VAN DE KLINKERS',
#        'POLLER IN WEGDEK GING OMHOOG', 'LAGEN STENEN OP DE WEG',
#        'ASVALT MET LOSLIGGEND GRIND', 'VOORZIEN VAN IJSLAAG SPEKGLAD',
#        'TEN VAL GEKOMEN GLAD WEGDEK', 'NVT', 'GLAD IJSLAAG OP HET WEGDEK',
#        'GLAS OP WEGDEK', 'LICHT VOCHTIG ', 'IN DE WASSTRAAT OP RAIL',
#        'ZANDPAD', 'MODDER OP WEG', 'WEGDEK BEDEKT MET SNEEUW',
#        'ONBEKEND ', 'FRIETVET OP DE WEG VERDEROP', 'BETON',
#        'UITGEGLEDEN DOOR GLAD WEGDEK', 'GLAD DOOR OPVRIEZING',
#        'MOGELIJK GLAD DOOR DE VRIESKOU', 'NAT DOOR SNEEUWVAL HEDENNACHT',
#        'DROOG GRAS', 'GLAD WEGDEK DOOR IJS SNEEUW', 'SLOOT', 'GRIND',
#        'OLIE SPOOR OP WEGDEK', 'LICHT OPVRIEZEND',
#        'MIJ VERBALISANT NIET BEKEND', 'MODDER',
#        'VEEL GRIND OP HET WEGDEK', 'LOS ZAND', 'HAGEL',
#        'GLAD DOOR MOGELIJKE BEVRIEZING', 'PEKEL',
#        'UITGEGLEDEN OVER HET WEGDEK', 'PAAL UIT WEGDEK', 'GLAD VAN IJZEL',
#        'GEVALLEN NAV WEGDEK', 'GEPEKELD', 'ZANDWEG',
#        'BESMEURD DOOR EIGEN OLIE', 'FIETSPAD LOSLIGGEND ZAND',
#        'ENIGSZINS GLAD DOOR OPVRIEZING', 'WETEN WE NIET', 'OLIE',
#        'TAK OP WEGDEK', 'ZEER LICHT OPGEVROREN', 'BESMEURD MET AARDE',
#        'VLOEISTOF OP WEGDEK', 'VERHOGING IN HET WEGDEK ',
#        'WAS ASFALT IS GEFREESD', 'VAL OP HET WEGDEK',
#        'BITUMEN MET DAARIN TRAMRAILS ', 'IN SLIP GEVALLEN OP WEGDEK',
#        'DIESEL OP WEGDEK', 'WEGDEKBENEVELING MET WATER',
#        'EENZIJDIG GLAD WEGDEK', 'BEDEKT MET ZAND', 'GLAD DOOR VRIESKOU',
#        'VEEL VRUCHTEN NOTEN VAN BOMEN', 'WAT LOS GRIND OP DE WEG',
#        'LAAG METALEN PAAL IN WEGDEK', 'KLINKERS', 'AANVRIEZEND VOCHTIG',
#        'VAN HET WEGDEK AFGEREDEN ', 'N V T ', 'TRAMSPOOR IN WEGDEK',
#        'GESLIPT TGV NAT WEGDEK', 'PAALTJE OP WEGDEK', 'ENIGSZINS GLAD',
#        'IN DE BOCHT LAG MODDER', 'ONVERHARD', 'LAG EEN KLEIN HOOPJE ZAND',
#        'KRAT OP WEGDEK', 'WEGDEK VERHOGING', 'GLAD DOOR IJZEL',
#        'BEVROREN STRAAT', 'BITUMEN MET SPOORRAILS',
#        'SLECHT WEGDEK BOOMWORTELS', 'OLIE OP WEGDEK',
#        'ZAND OP HET FIETSPAD', 'BEHOORLIJK VEEL SPLIT', 'LOSSE KIEZEL ',
#        'GLAD WEGDEK DOOR VORST', 'GLAD DOOR MIDDEL VAN VORST',
#        'OPENGEBROKEN', 'PAAL IN HET WEGDEK', 'HET WEGDEK',
#        'LOS GRIND ZAND', 'PLATEN OP WEG', 'PUIN GRIND',
#        'PAS AANGELEGD VEEL ZAND', 'UITLAAT DIE OP HET WEGDEK LAG ',
#        'PLAAT OP WEGDEK', 'PAPSNEEUW', 'SCHADE AAN WEGDEK',
#        'LANTAARN EN WEGDEK', 'GRIND VOOR DE HAAIENTANDEN',
#        'VOCHTIG HER EN DER IJSVORMING', 'AFDALING STIJGING WEGDEK',
#        'NIEUW GRIND VERDER DROOG', 'WW', 'GLADHEID DOOR BEVRIEZING',
#        'GESTROOIT', 'IETS VOCHTIG', 'UITGEGLEDEN IVM GLAD WEGDEK',
#        'OP HET WATER', 'ONVERHARD ZAND', 'HAAIENTANDEN OP HET WEGDEK',
#        'RAILS DROOG', 'WEGGEGLEDEN OP WEGDEK',
#        'WILDROOSTERS 2X IN WEGDEK', 'ZAND EN GRIND EN RIJPLATEN',
#        'FIETSER GEVALLEN OP WEGDEK', 'GLADWEGDEK', 'KUIL IN HET WEGDEK',
#        'VERDRIJVINGSVLAK OP WEGDEK', 'ZOAB', 'GLAD IVM VORST',
#        'WEGDEK HELT NAAR BENEDEN', 'REMMEN OP NAT WEGDEK', 'LOKAAL GLAD',
#        'TE HARD REMMEN OP GLAD WEGDEK ', 'BINNEN IN WINKELCENTRUM',
#        'MAASZAND OP WEGDEK GLAD ', 'BEDEKT MET DROOG ZAND',
#        'GLAD OPGEVROREN ', 'AANGEREDEN SNEEUW OP WEGDEK', 'BRUGWEGDEK',
#        'ONBEKEND NIET TER PLAATSE', 'HAGELLAAG', 'BESCHADIGING WEGDEK',
#        'TAKKEN OP DE WEG', 'PLAATSELIJK GLAD DOOR OLIE',
#        'LICHTE IJZEL GLAD ', 'WEGDEK BEVROREN', 'GLADHEID', 'OLIESPOOR',
#        'WEG VOL MET MODDER', 'HAD GEVROREN KON GLAD ZIJN',
#        'OPGEVROREN RIJBAAN', 'LOSLIGGENDE KIEZELS GRIND',
#        'ZAND EIGEN TERREIN', 'DOOR VORST WEL WAT GLAD ',
#        'ONBEKEND TEN TIJDE VAN ONGEVAL', 'GLAD REGEN EN VORST',
#        'ONBEKEND OBV CAMERABEELDEN', 'GLAD OPGEVROREN',
#        'PO DE VLUCHTSTROOK LAG IJS', 'TRAMBAAN WEGDEK',
#        'VERHOGING WEGDEK STOEPRAND ', 'POLLER IN WEGDEK',
#        'VLOEISTOFDICHTE VLOER', 'LOS GRIT', 'GLAD DOOR OLIESPOOR ',
#        'HER EN DER LICHTE MODDERSPOREN', 'DOOR OPVRIEZING WEGDEK GESLIPT',
#        'HEEL LICHT VOCHTIG', 'GEVALLEN OP WEGDEK', 'GLAD NAT',
#        'EENZIJDIG DOOR SLECHT WEGDEK', 'EIKELS OP HET FIETSPAD',
#        'VOL ZOUT', 'LICHTE VORST', 'VERHOGING IN HET WEGDEK',
#        'ZAND EN PUIN', 'WEGDEK GLAD DOOR OPVRIEZING',
#        'KIEZEL OP DE OPRIT', 'UITGEGLEDEN OVER WEGDEK',
#        'KOUD WEGDEK IVM VRIEZEN', 'LOS SPLIT', 'BRUG LATTEN',
#        'OMHOOGSTAAND STUK WEGDEK', 'ONGEVAL TEGEN WEGDEK GEVALLEN',
#        'GLAD WEGDEK NA DAG SNEEUWVAL ', 'GEEN IDEE NIET TP GEWEEST',
#        'GLAD WEGDEK DOOR OPVRIEZING ', 'GESTEENTE OP HET WEGDEK',
#        'AANGEVROREN WEGDEK', 'IJS OP WEG ZEER GLAD',
#        'HEEL LICHT OPGEVROREN', 'GLAD WEGDEK DOOR OPVRIEZEN',
#        'GLAD OPGEVROREN WEGDEK', 'VRIESKOU MOGELIJK GLADHEID',
#        'DOOR GLAD WEGDEK', 'ASVALT', 'GLAD OP SOMMIGE PLEKKEN',
#        'RIJP OP DE RIJBAAN', 'ONBEKEND OP DAT MOMENT', 'CONDENSVORMING',
#        'LANG GRAS', 'VOCHTIG LICHTELIJK OPGEVROREN',
#        'NAT VOCHTIG BLADEREN', 'UITGLIJDEN OP WEGDEK',
#        'WEGDEK VERVUILD MET MODDER', 'BEVROREN REGEN', 'WEGDEK EN BERM',
#        'HAGEL OP WEGDEK', 'VOL LOS ZAND', 'IJZEL EN WAS ZEER GLAD',
#        'STROOIZOUT', 'GRINDPAD', 'GLAD BEVROREN ',
#        'SLIPPEN DOOR NAT WEGDEK', 'NIET OP LOC INCIDENT GEWEEST',
#        'PAALTJE IN WEGDEK', 'GROND', 'VEEL KIEZELSTEENTJES',
#        'NOODSTOP OP NAT WEGDEK ', 'GLAD DOOR BLADEREN ',
#        'POLLERS IN HET WEGDEK', 'MODDER EN BLADEREN VOCHTIG',
#        'NIET VAST TE STELLEN ', 'NAT EN BLADEREN OP DE WEG',
#        'BEETJE VOCHTIG DOOR DE MIST ', 'VORST AAN DE GROND',
#        'GLAD ONBEKEND DOOR WAT ', 'VEEL BLADEREN', 'NIET MEER BEKEND',
#        'BLADEREN', 'ZAND OP DE RIJBAAN', 'VOCHTIG',
#        'HEKWERK NAAST WEGDEK', 'VALLEND BLAD', 'STOND GEPERKEERD',
#        'STALEN RIJPLATEN', 'OLIE OP WEGDEK ', 'POLITIE NIET TP',
#        'NAT EN OLIESPOOR OP DE WEG', 'MODDER ZAND', 'LOSSE ZAND',
#        'VOORRANGSTEKENS OP HET WEGDEK', 'BIJENKORF GARAGE',
#        'DOORGLIJDEN GLAD WEGDEK', 'ONDERUIT DOOR GLAD WEGDEK',
#        'VERHARD VOETPAD', 'GLAD IVM VRIESTEMPERATUREN', 'IJSEL OP DE WEG',
#        'NAT IJZEL', 'EENZIJDIG DOOR OLIE OP WEGDEK',
#        'WEGGEGLEDEN DOOR GLAD WEGDEK', 'VRIES KOU',
#        'GESPINT OP HET GLADDE WEGDEK ', 'MIDDENGELEIDER OP HET WEGDEK',
#        'STOEPTEGELS', 'BETREFT BOUWTERREIN', 'VERHOGING OP WEGDEK',
#        'VALPARTIJ BOTSING MET WEGDEK', 'WASSTRAAT',
#        'NAT EN DEELS BESMEURD', 'LAGEN EIKELS', 'GAT IN HET WEGDEK',
#        'GRAS VOCHTIG', 'LICHTE GLADHEID DOOR VORST',
#        'LOSLIGGENDE BLADEREN', 'AANGEVROREN ', '90KM H BIJ NAT WEGDEK',
#        'BEVROREN EN BLADRESTEN ', 'NAT WEGDEK WAT OPGEVROREN WAS',
#        'OLIESPOOR OP WEGDEK', 'REGEN ICM MODDER',
#        'DROOG FLINKE LAAG SPLIT ZAND', 'VERHOGING VAN HET WEGDEK',
#        'SPLIT OP HET WEGDEK', 'ONBEKEND BIJ POLITIE', 'KLEI OP DE WEG',
#        'TRAMBAAN OP WEGDEK', 'GRAS WAS VOCHTIG VAN DOUW', 'GEEN',
#        'ONDER DE MODDER', 'GLAD DOOR RIJP', 'VEEL LOS GRIND OP WEGDEK',
#        'LICHT VERVUILD', 'IS NIET MEER TE ACHTERHALEN',
#        'BESMEURD MET DIKKE LAAG MODDER', 'GLAD GRAS DOOR OPVRIEZING',
#        'BLADEREN OP WEGDEK ', 'GLAD NAT VOCHTIG',
#        'KLINKERS OVERGAAND IN REPACK', 'ONDERUIT GEGAAN OP HET WEGDEK',
#        'BOTSING WEGDEK', 'VEEL ZAND OP DE VERHARDE WEG',
#        'ONBEKEND NIET TP GEWEEST', 'MOGELIJK BEVROREN',
#        'STRAATZAND KLINKERS', 'TEGELVLOER', 'ZON', 'BLAD OP FIETSPAD',
#        'GLAD VRIES', 'NIET TER PLAATSE'], dtype=object)
# BZD_VM_AN
# array(['geslotenverklaring', 'VRI aanwezig', 'Matrixborden',
#        'Rijstrooksignalering', 'keerverbod', 'gesloten verklaring',
#        'inhaalverbod', 'VRI niet aanwezig', 'werkend matrixbord',
#        'wegafzetting', 'voetgangersgebied', 'UITRIT',
#        'snelheidsbeperking', 'matrixborden'], dtype=object)
# BZD_IF_AN
# array(['In/uitrit', 'voetgangersgebied', 'geslotenverklaring', ...,
#        'NABIJ TOERIT VAN DE SNELWEG', 'NA EEN KRUISPUNT',
#        'OPRIT NAAR SNELWEG A4 RECHTS'], dtype=object)
# BZD_TA_AN
# array(['Wegomlegging', 'geslotenverklaring', 'tijdelijke afsluiting',
#        'gesloten vedrklaring', 'afsluiting', 'tijdelijk inrijverbod',
#        'wegafzetting', 'tijdelijke omleiding', 'inhaalverbod',
#        'omleiding', 'afzetting', 'wegafsluiting', 'parkeerverbod',
#        'GESLOTEN VERKLARING', 'wegomlegging'], dtype=object)

# %% [markdown]
# ### Voeg alles samen tot dataframe
# - Hier word de partijen_df gekoppeld aan het ongevallen_df, hierdoor is is er meer informatie over het voertuig gekoppeld aan de de ongeluk locaties. De sleutels van de dat worden respectievelijk, 'PTJ_ID' en 'VKL_NUMMER'.
# - Vervolgens moeten we alle waardes in de columnen opnieuw gaan coderen zodat er een analyses over gedaan kan worden
# - Voordat we kunnen hercoderen moeten we eerst alle NaN values omzetten in iets werkbaars, voor string columen zetten NaN om in 'NaN', in numerieke columns transformeren we NaN naar 0
# - Na het creeren van deze dataset kunnne we beginnne met de analyse en het maken van het model.

# %%
df_total_final = df_total[cols_zondAlt]

# Check for columns with missing values
missing_val_cols = df_total_final.columns[df_total_final.isnull().any()]

# fill missing values with something we can work with
for col in missing_val_cols:
    if df_total_final[col].dtypes == object:
        df_total_final[col].fillna('NaN', inplace=True)
    if df_total_final[col].dtypes == float:
        df_total_final[col].fillna(0, inplace=True)

        
# Check the data
df_total_final.info()
# display(df_total_final.describe(include='all'))
display(df_total_final.head())
# Out:
# /home/smwhering/miniconda3/envs/datasc/lib/python3.7/site-packages/pandas/core/series.py:4469: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1224079 entries, (25387133, 20110060504, 'WVK0261442006') to (28156355, 20190078934, 'WVK0403127004')
# Data columns (total 26 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   ANTL_PTJ    1224079 non-null  int64
#  1   AOL_ID      1224079 non-null  int64
#  2   AP3_CODE    1224079 non-null  object
#  3   BEBKOM      1224079 non-null  object
#  4   BZD_ID_IF1  1224079 non-null  float64
#  5   BZD_ID_IF2  1224079 non-null  float64
#  6   BZD_ID_TA1  1224079 non-null  float64
#  7   BZD_ID_TA2  1224079 non-null  float64
#  8   BZD_ID_VM1  1224079 non-null  float64
#  9   BZD_ID_VM2  1224079 non-null  float64
#  10  BZD_ID_VM3  1224079 non-null  float64
#  11  GME_NAAM    1224079 non-null  object
#  12  IND_ALC     1224079 non-null  object
#  13  LGD_ID      1224079 non-null  float64
#  14  MAXSNELHD   1224079 non-null  float64
#  15  NIVEAUKOP   1224079 non-null  object
#  16  NUMMER      1224079 non-null  int64
#  17  OTE_ID      1224079 non-null  float64
#  18  PVE_NAAM    1224079 non-null  object
#  19  WDK_ID      1224079 non-null  float64
#  20  WGD_CODE_1  1224079 non-null  object
#  21  WGD_CODE_2  1224079 non-null  object
#  22  WSE_ID      1224079 non-null  float64
#  23  WVG_ID      1224079 non-null  float64
#  24  WVL_ID      1224079 non-null  float64
#  25  ZAD_ID      1224079 non-null  float64
# dtypes: float64(15), int64(3), object(8)
# memory usage: 329.5+ MB
#                                     ANTL_PTJ  AOL_ID AP3_CODE BEBKOM  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006         2       6      LET    NaN
# 25387134 20110060504 WVK0261442006         2       6      LET    NaN
# 25387135 20110060555 WVK0219488003         1       9      LET    NaN
# 25387138 20110060600 WVK0224440001         2       4      LET    NaN
# 25387139 20110060600 WVK0224440001         2       4      LET    NaN
#
#                                     BZD_ID_IF1  BZD_ID_IF2  BZD_ID_TA1  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006         0.0         0.0         0.0
# 25387134 20110060504 WVK0261442006         0.0         0.0         0.0
# 25387135 20110060555 WVK0219488003         0.0         0.0         0.0
# 25387138 20110060600 WVK0224440001         0.0         0.0         0.0
# 25387139 20110060600 WVK0224440001         0.0         0.0         0.0
#
#                                     BZD_ID_TA2  BZD_ID_VM1  BZD_ID_VM2  ...  \
# PTJ_ID   VKL_NUMMER  FK_VELD5                                           ...
# 25387133 20110060504 WVK0261442006         0.0         0.0         0.0  ...
# 25387134 20110060504 WVK0261442006         0.0         0.0         0.0  ...
# 25387135 20110060555 WVK0219488003         0.0         0.0         0.0  ...
# 25387138 20110060600 WVK0224440001         0.0         0.0         0.0  ...
# 25387139 20110060600 WVK0224440001         0.0         0.0         0.0  ...
#
#                                     NUMMER OTE_ID       PVE_NAAM  WDK_ID  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006       1   64.0  Noord-Holland     1.0
# 25387134 20110060504 WVK0261442006       2   64.0  Noord-Holland     1.0
# 25387135 20110060555 WVK0219488003       1    0.0  Noord-Holland     0.0
# 25387138 20110060600 WVK0224440001       1   62.0  Noord-Holland     1.0
# 25387139 20110060600 WVK0224440001       2   83.0  Noord-Holland     1.0
#
#                                     WGD_CODE_1 WGD_CODE_2  WSE_ID  WVG_ID  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006           D        NaN     1.0     2.0
# 25387134 20110060504 WVK0261442006           D        NaN     1.0     2.0
# 25387135 20110060555 WVK0219488003           O        NaN     2.0     0.0
# 25387138 20110060600 WVK0224440001           D        NaN     1.0     4.0
# 25387139 20110060600 WVK0224440001           D        NaN     1.0     4.0
#
#                                    WVL_ID  ZAD_ID
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006    3.0     0.0
# 25387134 20110060504 WVK0261442006    3.0     0.0
# 25387135 20110060555 WVK0219488003    0.0     0.0
# 25387138 20110060600 WVK0224440001    2.0     0.0
# 25387139 20110060600 WVK0224440001    2.0     0.0
#
# [5 rows x 26 columns]

# %%
ID_cols = set([col for col in df_total_final.columns if '_ID' in col])
print(ID_cols)
# print(df_dct.keys())

# df_dct['bijzonderheden_df']


# for df in df_dct:
#     if df != 'ongevallen_df' and df != 'partijen_df':
#         cols = set(df_dct[df].columns)
#         inters = list(ID_cols & cols)
#         if inters:
#             df_total_final[inters[0]] = df_total_final[inters[0]].map(df_dct[df].set_index(inters[0])[:,0])
        
    
df_dct['aardongevallen_df'].set_index('AOL_ID')['AOL_OMS']
# Out:
# {'AOL_ID', 'BZD_ID_VM1', 'WSE_ID', 'OTE_ID', 'WVL_ID', 'BZD_ID_VM3', 'BZD_ID_IF1', 'BZD_ID_VM2', 'BZD_ID_IF2', 'WDK_ID', 'WVG_ID', 'ZAD_ID', 'LGD_ID', 'BZD_ID_TA1', 'BZD_ID_TA2'}
# AOL_ID
# 3                   Dier
# 9              Eenzijdig
# 7                  Flank
# 6               Frontaal
# 2    Geparkeerd voertuig
# 8             Kop/staart
# 5           Los voorwerp
# 0               Onbekend
# 4          Vast voorwerp
# 1             Voetganger
# Name: AOL_OMS, dtype: object

# %%
fig, axs = plt.subplots(nrows=6, ncols=5, figsize=(30,30))

count_df = df_total_final.apply(pd.value_counts)
for col, ax in zip(count_df, axs.flatten()):
    count_df[col].dropna().plot(kind='bar', ax = ax, legend=True, logy=True)

    
# Split the data into features and target, for this research we want to predict the serverity of an accident based on al the other
X = df_total_final.loc[:, df_total_final.columns != 'AP3_CODE']
Y = df_total_final.loc[:, ['AP3_CODE']]
display(Y.head())
display(X.head())


# count_df.plot(subplots=True, layout=(10,5), figsize=(20,20))

# enc = OrdinalEncoder()
# objectcols = df_total_final.loc[:, df_total_final.dtypes == object].columns

# df_total_final.loc[:, objectcols] = enc.fit_transform(df_total_final.loc[:, objectcols])
# print(enc.categories_)
# df_total_final.head()
# df_total_final.info()

# corr = df_total_final.corr('pearson')
# mask = np.zeros_like(corr)
# mask[np.triu_indices_from(mask)] = True
# with sb.axes_style("white"):
#     f, ax = plt.subplots(figsize=(7, 5))
#     ax = sb.heatmap(corr, mask=mask, vmax=.3, square=True)
# Out:
#                                    AP3_CODE
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006      LET
# 25387134 20110060504 WVK0261442006      LET
# 25387135 20110060555 WVK0219488003      LET
# 25387138 20110060600 WVK0224440001      LET
# 25387139 20110060600 WVK0224440001      LET
#                                     ANTL_PTJ  AOL_ID BEBKOM  BZD_ID_IF1  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006         2       6    NaN         0.0
# 25387134 20110060504 WVK0261442006         2       6    NaN         0.0
# 25387135 20110060555 WVK0219488003         1       9    NaN         0.0
# 25387138 20110060600 WVK0224440001         2       4    NaN         0.0
# 25387139 20110060600 WVK0224440001         2       4    NaN         0.0
#
#                                     BZD_ID_IF2  BZD_ID_TA1  BZD_ID_TA2  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006         0.0         0.0         0.0
# 25387134 20110060504 WVK0261442006         0.0         0.0         0.0
# 25387135 20110060555 WVK0219488003         0.0         0.0         0.0
# 25387138 20110060600 WVK0224440001         0.0         0.0         0.0
# 25387139 20110060600 WVK0224440001         0.0         0.0         0.0
#
#                                     BZD_ID_VM1  BZD_ID_VM2  BZD_ID_VM3  ...  \
# PTJ_ID   VKL_NUMMER  FK_VELD5                                           ...
# 25387133 20110060504 WVK0261442006         0.0         0.0         0.0  ...
# 25387134 20110060504 WVK0261442006         0.0         0.0         0.0  ...
# 25387135 20110060555 WVK0219488003         0.0         0.0         0.0  ...
# 25387138 20110060600 WVK0224440001         0.0         0.0         0.0  ...
# 25387139 20110060600 WVK0224440001         0.0         0.0         0.0  ...
#
#                                    NUMMER OTE_ID       PVE_NAAM  WDK_ID  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006      1   64.0  Noord-Holland     1.0
# 25387134 20110060504 WVK0261442006      2   64.0  Noord-Holland     1.0
# 25387135 20110060555 WVK0219488003      1    0.0  Noord-Holland     0.0
# 25387138 20110060600 WVK0224440001      1   62.0  Noord-Holland     1.0
# 25387139 20110060600 WVK0224440001      2   83.0  Noord-Holland     1.0
#
#                                    WGD_CODE_1  WGD_CODE_2  WSE_ID WVG_ID  \
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006          D         NaN     1.0    2.0
# 25387134 20110060504 WVK0261442006          D         NaN     1.0    2.0
# 25387135 20110060555 WVK0219488003          O         NaN     2.0    0.0
# 25387138 20110060600 WVK0224440001          D         NaN     1.0    4.0
# 25387139 20110060600 WVK0224440001          D         NaN     1.0    4.0
#
#                                     WVL_ID ZAD_ID
# PTJ_ID   VKL_NUMMER  FK_VELD5
# 25387133 20110060504 WVK0261442006     3.0    0.0
# 25387134 20110060504 WVK0261442006     3.0    0.0
# 25387135 20110060555 WVK0219488003     0.0    0.0
# 25387138 20110060600 WVK0224440001     2.0    0.0
# 25387139 20110060600 WVK0224440001     2.0    0.0
#
# [5 rows x 25 columns]

# %%
# for df in df_dct:
#     print('Name of dataframe: {}'.format(df))
#     display(df_dct[df].head())

# %% [markdown]
# ### Data Analyse

# %%
# fig, ax = plt.subplots(figsize = (20,15))
# df_total.hist(layout=(10,6), legend=True, ax = ax)

# sb.pairplot(partijen_df, corner=True)

# %% [markdown]
# ### Visualisatie: Ongevallen

# %% [markdown]
# Vervolgens kijken we naar de columen opzich om te kunnen achterhalen waar de meeste rijen zich bevinden.

# %%
# sb.pairplot(ongevallen_sub, corner=True)

# %%
# fig, ax = plt.subplots(figsize = (20,15))
# ongevallen_totaal.hist(layout=(10,6), legend=True, ax = ax)

# %% [markdown]
# ### Visualisatie: Partijen

# %%
# sb.pairplot(partijen_df, corner=True)

# %%
# fig, ax = plt.subplots(figsize = (20,15))
# partijen_df.hist(layout=(5,3), legend=True, ax = ax)

# %% [markdown]
# ````{margin}
# ```{note}
# Here is a note!
# ```
# ````
